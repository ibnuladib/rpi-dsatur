# %% [markdown]
# # RPI-DSATUR results analysis
#
# Produces the 11 figures/tables required by final_spec.md. Reads existing matrix JSONLs plus newly generated results/fixed_radius_sweep.jsonl and results/hop_coverage.csv. Does not read results/raw_outcomes.jsonl.
#
# Re-run: `python notebooks/results_analysis.py` or execute all cells below.

# %% [markdown]
# ## Setup

# %%
import os
import sys
from pathlib import Path

from IPython.display import Image, display
import pandas as pd

ROOT = Path.cwd()
if not (ROOT / "results" / "matrix_static_systems.jsonl").exists():
    ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))
sys.path.insert(0, str(ROOT / "notebooks"))

DATA_DIR = ROOT / "results"
FIGURES_DIR = ROOT / "results" / "figures"
TABLES_DIR = ROOT / "results" / "tables"
os.makedirs(FIGURES_DIR, exist_ok=True)
os.makedirs(TABLES_DIR, exist_ok=True)

import results_analysis as ra
# Force module paths to this ROOT (in case the kernel cwd differed at import).
ra.ROOT = ROOT
ra.DATA_DIR = DATA_DIR
ra.FIGURES_DIR = FIGURES_DIR
ra.TABLES_DIR = TABLES_DIR

print("ROOT =", ROOT)
print("FIGURES_DIR =", FIGURES_DIR)
print("TABLES_DIR =", TABLES_DIR)

# %% [markdown]
# ## Produce all artifacts
#
# Runs the full Part-2 generator (writes every figure PNG and table CSV). Subsequent cells display each artifact.

# %%
info = ra.generate_all()
print(info)

# %% [markdown]
# ## Figure 1 — `fig1_combined_scaling`
#
# Median time_ms (log y) vs n (log x) for full_recompute and rpi_dsatur (single combined holdout+OOD chart).

# %%
p = FIGURES_DIR / "fig1_combined_scaling.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 2 — `fig2_hop_coverage_vs_n`
#
# Mean 4-hop coverage_fraction with IQR vs n (log x).

# %%
p = FIGURES_DIR / "fig2_hop_coverage_vs_n.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 3 — `fig3_fallback_vs_n`
#
# Fallback rate (%) vs n; all 4 systems for n<=500, RPI+full at n=2000.

# %%
p = FIGURES_DIR / "fig3_fallback_vs_n.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 4 — `fig4_vertices_vs_n`
#
# Mean vertices_touched vs n for every system available at each size.

# %%
p = FIGURES_DIR / "fig4_vertices_vs_n.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 5 — `fig5_edit_type_breakdown`
#
# Grouped bars: fallback rate and mean vertices_touched by edit_type x system.

# %%
p = FIGURES_DIR / "fig5_edit_type_breakdown.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 6 — `fig6_confusion_heatmap`
#
# Heatmap of the hop-shell classifier confusion matrix (rows=true, cols=predicted).

# %%
p = FIGURES_DIR / "fig6_confusion_heatmap.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 7 — `fig7_per_class_recall`
#
# Per-class recall bars annotated with support count n.

# %%
p = FIGURES_DIR / "fig7_per_class_recall.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 8 — `fig8_misprediction_cost`
#
# RPI time_ms and vertices_touched for first-try (attempts==0) vs retried (attempts>0).

# %%
p = FIGURES_DIR / "fig8_misprediction_cost.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Figure 9 — `fig9_fixed_radius_sweep`
#
# Median time_ms and fallback rate vs fixed radius in {1,2,3,4}.

# %%
p = FIGURES_DIR / "fig9_fixed_radius_sweep.png"
assert p.exists(), f"missing {p} — re-run the produce cell"
display(Image(filename=str(p)))
print(p)

# %% [markdown]
# ## Table 10 — `table_wilcoxon_full`
#
# Six edit-level Wilcoxon rows + Holm-Bonferroni + parallel graph-level tests.

# %%
p = TABLES_DIR / "table_wilcoxon_full.csv"
assert p.exists(), f"missing {p} — re-run the produce cell"
df = pd.read_csv(p)
display(df)
print(p)

# %% [markdown]
# ## Table 11 — `table_headline_summary`
#
# Four-system headline summary re-rendered from the holdout JSONLs.

# %%
p = TABLES_DIR / "table_headline_summary.csv"
assert p.exists(), f"missing {p} — re-run the produce cell"
df = pd.read_csv(p)
display(df)
print(p)

# %% [markdown]
# ## Done
#
# Artifacts: `results/figures/*.png`, `results/tables/*.csv`.
